# %%
import cv2

def list_available_cameras(max_index=10):
    """Returns a list of available camera indices."""
    available_cameras = []
    for i in range(max_index):
        cap = cv2.VideoCapture(i)
        if cap.isOpened():
            available_cameras.append(i)
            cap.release()
    return available_cameras

# Example usage
print("Available cameras:", list_available_cameras())
# Out:
# [01/03 00:09:30.032106][info][1488113][Context.cpp:69] Context created with config: default config!
# [01/03 00:09:30.032153][info][1488113][Context.cpp:74] Context work_dir=/Users/wongdowling/Documents/Darth_vaccuu/ROS
# [01/03 00:09:30.032156][info][1488113][Context.cpp:77] 	- SDK version: 1.9.4
# [01/03 00:09:30.032158][info][1488113][Context.cpp:78] 	- SDK stage version: main
# [01/03 00:09:30.032163][info][1488113][Context.cpp:82] get config EnumerateNetDevice:false
# [01/03 00:09:30.032166][info][1488113][MacPal.cpp:36] createObPal: create MacPal!
# [01/03 00:09:30.035218][info][1488113][MacPal.cpp:104] Create PollingDeviceWatcher!
# [01/03 00:09:30.035232][info][1488113][DeviceManager.cpp:15] Current found device(s): (0)
# [01/03 00:09:30.035237][info][1488113][Pipeline.cpp:15] Try to create pipeline with default device.
# [01/03 00:09:30.035241][warning][1488113][ObException.cpp:5] No device found, fail to create pipeline!
# ...

# %%
def start_video_stream(camera_index=0):
    """Starts video streaming with error handling."""
    cap = cv2.VideoCapture(camera_index)
    
    if not cap.isOpened():
        print(f"Cannot open camera {camera_index}")
        return
    
    # Set resolution (optional)
    cap.set(cv2.CAP_PROP_FRAME_WIDTH, 640)
    cap.set(cv2.CAP_PROP_FRAME_HEIGHT, 480)
    
    print(f"Streaming video from camera {camera_index}. Press 'q' to quit.")
    
    while True:
        ret, frame = cap.read()
        if not ret:
            print("Failed to grab frame. Check your camera.")
            break
        
        cv2.imshow('Camera Stream', frame)
        
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
    
    cap.release()
    cv2.destroyAllWindows()

# Example usage
camera_index = 1
start_video_stream(camera_index)
# Out:
# Streaming video from camera 1. Press 'q' to quit.
# Failed to grab frame. Check your camera.
